# %%
import cv2
from matplotlib import pyplot as plt
from digi_extract import extract_line, extract_sym

# %%
"""Image file"""
imagefile = 'C:/Users/shubh/Downloads/img16.jpg'

# %%
"""Reading and plotting image"""
image = cv2.imread(imagefile,0)
plt.imshow(image,cmap='gray')
plt.show()

# %%
"""detecting and plotting written area"""
line = extract_line(image)
plt.imshow(line,cmap='gray')
plt.show()

# %%
"""getting list of digit and symbol images"""
digilist = extract_sym(line)
len(digilist)
# Out:
# 10

# %%
"""plotting first digit"""
plt.imshow(digilist[0],cmap='gray')
plt.show()

# %%
"""plotting last digit"""
plt.imshow(charlist[9],cmap='gray')
plt.show()
